# %%
import pandas as pd

# %%
atmiya = pd.read_csv("final aatmiya realty.csv")
atmiya
# Out:
#      Pdf No Bill no     Name       Party Name Invoice no   Bill Date  \
# 0         1    1446  Darshan        DOSHI INC       1106  28-01-2014
# 1         1       0  Darshan        DOSHI INC          0  02-08-2014
# 2         1       0  Darshan        DOSHI INC          0  02-08-2014
# 3         1    1555  Darshan  CERAMICA GALAXY        637  22-02-2014
# 4         1    1444  Darshan       TOP BRICKS          1  31-01-2014
# ...     ...     ...      ...              ...        ...         ...
# 6713     50     NaN   SUDHIR  SPEED ELEVATORS        392  31-03-2021
# 6714     50     NaN   SUDHIR  SPEED ELEVATORS        385  31-03-2021
# 6715     50     NaN   SUDHIR  SPEED ELEVATORS        386  31-03-2021
# 6716     50     NaN   SUDHIR  SPEED ELEVATORS        315  31-03-2021
# 6717     50     NaN   SUDHIR  SPEED ELEVATORS        320  31-03-2015
#
#       Paid Date  Purchase Voucher  General Voucher      Material Code    Qty  \
# ...

# %%
atmiya.columns
# Out:
# Index(['Pdf No', 'Bill no', 'Name', 'Party Name', 'Invoice no', 'Bill Date',
#        'Paid Date', 'Purchase Voucher', 'General Voucher', 'Material Code',
#        'Qty', 'Unit', 'Basic Amount', 'GST', 'VAT', 'TDS', 'Total',
#        'Company Name', 'PDF URL'],
#       dtype='object')

# %%
atmiya['Name'].dtypes
# Out:
# dtype('O')

# %%
a = pd.DataFrame(atmiya)
print(a.dtypes)
# Out:
# Pdf No               object
# Bill no              object
# Name                 object
# Party Name           object
# Invoice no           object
# Bill Date            object
# Paid Date           float64
# Purchase Voucher    float64
# General Voucher     float64
# Material Code        object
# Qty                  object
# Unit                 object
# Basic Amount         object
# GST                 float64
# VAT                  object
# TDS                  object
# Total                object
# Company Name         object
# PDF URL              object
# dtype: object

# %%
    atmiya[atmiya["Name"] == "Darshan"]
# Out:
#       Pdf No Bill no     Name           Party Name Invoice no   Bill Date  \
# 0          1    1446  Darshan            DOSHI INC       1106  28-01-2014
# 1          1       0  Darshan            DOSHI INC          0  02-08-2014
# 2          1       0  Darshan            DOSHI INC          0  02-08-2014
# 3          1    1555  Darshan      CERAMICA GALAXY        637  22-02-2014
# 4          1    1444  Darshan           TOP BRICKS          1  31-01-2014
# ...      ...     ...      ...                  ...        ...         ...
# 1048  1/1900       0  Darshan        JAGDISH YADAV          0  26-05-2018
# 1049  1/1900       0  Darshan  ADITYA COROPORATION        441  26-05-2018
# 1050  1/1900    6852  Darshan   SHEETAL PAPER MART        190  11-04-2018
# 1051  1/1900       0  Darshan   GUJARAT ENTERPRISE        202  28-04-2018
# 1052  1/1900       0  Darshan   MANUSHI ENTERPRISE        160  07-12-2017
#
#       Paid Date  Purchase Voucher  General Voucher      Material Code    Qty  \
# ...
